# %% [markdown]
# <a href="https://colab.research.google.com/github/kvraagul/Innomatics_Internship_APR_21/blob/main/Task_1_(Descriptive_Statistics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INNOMATICS INTERNSHIP APRIL 2021**
#
# **Task_1 (Descriptive Statistics).**

# %%
import pandas as pd

dataset = pd.read_csv('data.csv')

# %% [markdown]
# # MEAN
#
# Mean is an average
#
# Mean = Sum of N / Total no of N

# %%
dataset.mean()
# Out:
# Mthly_HH_Income           41558.00
# Mthly_HH_Expense          18818.00
# No_of_Fly_Members             4.06
# Emi_or_Rent_Amt            3060.00
# Annual_HH_Income         490019.04
# No_of_Earning_Members         1.46
# dtype: float64

# %% [markdown]
# # Median
#
# Median is the middle value after sorting it in asceding order

# %%
dataset.median()
# Out:
# Mthly_HH_Income           35000.0
# Mthly_HH_Expense          15500.0
# No_of_Fly_Members             4.0
# Emi_or_Rent_Amt               0.0
# Annual_HH_Income         447420.0
# No_of_Earning_Members         1.0
# dtype: float64

# %% [markdown]
# # Mode
#
# Mode is the most repeated value in the dataset

# %%
dataset.mode()
# Out:
#    Mthly_HH_Income  ...  No_of_Earning_Members
# 0            45000  ...                      1
#
# [1 rows x 7 columns]

# %% [markdown]
# # Variance
#
# Variance is the average of squared distance from mean
#
# ![Capture-103.jpg](data:image/jpeg;base64,...)

# %%
dataset.var()
# Out:
# Mthly_HH_Income          6.811009e+08
# Mthly_HH_Expense         1.461733e+08
# No_of_Fly_Members        2.302449e+00
# Emi_or_Rent_Amt          3.895551e+07
# Annual_HH_Income         1.024869e+11
# No_of_Earning_Members    5.391837e-01
# dtype: float64

# %% [markdown]
# # Standard Deviation
#
# Standard Deviation is the average distance from mean
#
# It is denoted by σ
#
# ![standard-deviation-formula.png](data:image/png;base64,...)

# %%
dataset.std()
# Out:
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64

# %% [markdown]
# # Correlation
#
# Corrleation is used to measure the strength of the relationship between two random variables
#
# 1 indicates a strong positive relationship
#
# -1 indicated a strong negative relationship
#
# 0 indicates a no relationship between two values
#
# ![How to Get Correlation Coefficient in Power BI.png](data:image/png;base64,...)
#
# ![Correlation-Coefficient-Formula.jpg.jfif](data:image/jpeg;base64,...)

# %%
dataset.corr()
# Out:
#                        Mthly_HH_Income  ...  No_of_Earning_Members
# Mthly_HH_Income               1.000000  ...               0.347883
# Mthly_HH_Expense              0.649215  ...               0.311915
# No_of_Fly_Members             0.448317  ...               0.597482
# Emi_or_Rent_Amt               0.036976  ...              -0.097431
# Annual_HH_Income              0.970315  ...               0.296679
# No_of_Earning_Members         0.347883  ...               1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# # Normal Distribution
#
# It is a probability distribution that is symmetric about the mean, showing that the data near mean are more frequent in occurence than data from far the mean.
#
# It is also called as Bell Curve
#
# It is a distribution that occurs naturally in many situations.
#
# ![normal-distribution-formula.png](data:image/png;base64,...)

# %% [markdown]
# **Normal Distribution Empherical Formula**
#
# The Empirical Rule states that 99.7% of data observed following a normal distribution lies within 3 standard deviations of the mean. Under this rule, 68% of the data falls within one standard deviation, 95% percent within two standard deviations, and 99.7% within three standard deviations from the mean.
#
# ![the_normal_distribution_empirical_rule_8.png](data:image/png;base64,...)

# %% [markdown]
# **Properties of Normal Distribution**
#
# * The mean, mode and median are all equal.
#
# * The curve is symmetric at the center (i.e. around the mean, μ).
#
# * Exactly half of the values are to the left of center and exactly half the values are to the right.
#
# * The total area under the curve is 1.

# %% [markdown]
# # Skewness of Data
#
#   Skweness is the measure of how much the probability distribution of a random variable deviates from the normal distribution.
#
# 1. The skewness for a normal distribution is zero, and any symmetric data should have a skewness near zero. (eg: Age distribution, Height and Weight
# distribution)
# Mean = Median = Mode
#
# 2. Negative values for the skewness indicate data that are skewed left. (eg: Life span of human)
# Mode > Median > Mean
#
# 3. Positive values for the skewness indicate data that are skewed right. (eg: Wealth Distribution)
# Mean > Median > Mode
#
#  ![651px-Relationship_between_mean_and_median_under_different_skewness.png](data:image/png;base64,...)

# %% [markdown]
# # Quantile-Quantile Plot
#
#
# * Q-Q Plot are scatter plot of two quantiles against each other, the purpose of Q-Q plot is to find out if two data sets comes from same distribution
#
# * A 45-degree angle is plotted if two data sets comes from a common distribution, the points will fall on that reference line
#
# ![450px-Normal_normal_qq.svg.png](data:image/png;base64,...)

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
  

data_points = np.random.normal(0, 1, 100)    
  
sm.qqplot(data_points, line ='45')
py.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Box Cox Transformation
#
# * Data transforms are usually applied so that the data appear to more closely meet assumptions of a statistical inference model to be applied or to improve the interpret-ability or appearance of graphs.
#
# * Power transformation is a class of transformation functions that raise the response to some power. For example, a square root transformation converts X to X1/2
#
# **The formula of the Box Cox transformation is:**
# ![Box-Cox-EQ1.png](data:image/png;base64,...)
#
# Where:
#
# y is the transformation result
#
# x is the variable under transformation
#
# λ is the transformation parameter
